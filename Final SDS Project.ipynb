# %% [markdown]
# 📚 Libraries Used in This Project
# To perform statistical analysis and visualizations on the Student Enrollment dataset, several Python libraries were used. Each library contributes to data handling, statistical computations, or visual representation of the data.
#
# pandas
#
# Used for loading, cleaning, and manipulating the dataset.
#
# Enables filtering, grouping, sorting, and summarizing data efficiently.
#
# Plays a key role in data wrangling and exploration.
#
# NumPy
#
# Supports efficient numerical computations and array operations.
#
# Used for calculating statistical measures like mean, median, mode, and more.
#
# Matplotlib
#
# A versatile library used to build visualizations such as bar charts, histograms, and line plots.
#
# Allows full control over chart aesthetics including titles, axes, legends, and colors.
#
# Seaborn
#
# Built on top of Matplotlib, it simplifies the process of creating attractive and informative statistical graphics.
#
# Used for complex plots like boxplots, pairplots, and heatmaps, which help in analyzing distribution and relationships between variables

# %%
# Required Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 🎯 Objective of This Project:
# To conduct Exploratory Data Analysis (EDA) and apply descriptive statistics techniques to uncover insights regarding:
#
# Distribution of educational programs across universities
#
# Enrollment trends across levels of study
#
# Popular disciplines and program types
#
# Relationships between academic level, faculty, and program offerings

# %%
# Load dataset
df = pd.read_csv(r"C:\Users\kumar\OneDrive\Desktop\Student_Enrollment_courses-2015.csv")

# %% [markdown]
# 📊 Dataset Introduction
# 🎯 Dataset Name: Student Enrollment Courses - 2015
#
# 📝 Source: The dataset was sourced from an open government or academic repository, likely linked to higher education analytics and student enrollment statistics in India.
#
# 📦 Dataset Overview:
#
# Rows (Records): 68,017
#
# Columns (Features): 12
#
# File Format: CSV
#
# 🧩 Key Columns in the Dataset:
#
# University_name, faculty_name, department_name – Institution and academic details
#
# levell – Education level (e.g., Under Graduate, Post Graduate, Ph.D.)
#
# programme, programme_id – Program and its ID
#
# discipline_group, discipline – Academic discipline categorization
#
# type – Type of program (e.g., General, Self Financing)
#
# survey_year – Year of data collection (all are from 2015)

# %%
# Quick Overview
print("Dataset Shape:", df.shape)
print("\nInfo:")
print(df.info())
print("\nFirst 5 Rows:")
print(df.head())
# Out:
# Dataset Shape: (68017, 12)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68017 entries, 0 to 68016
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   University_id        68017 non-null  int64
#  1   University_name      68017 non-null  object
#  2   survey_year          68017 non-null  int64
#  3   faculty_name         62872 non-null  object
#  4   department_name      32195 non-null  object
#  5   levell               68017 non-null  object
#  6   programme_id         68017 non-null  int64
#  7   programme            68017 non-null  object
#  8   discipline_group_id  68017 non-null  int64
#  9   discipline_group     68017 non-null  object
#  10  discipline           68007 non-null  object
#  11  type                 68017 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 6.2+ MB
# None
#
# First 5 Rows:
# ...

# %%
# ========== UNIVARIATE ANALYSIS ==========

# %%
# Summary Statistics (Numerical)
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#        University_id  survey_year  programme_id  discipline_group_id
# count   68017.000000      68017.0  68017.000000         68017.000000
# mean      380.095947       2015.0    100.624300            75.781731
# std       211.743383          0.0     49.316702            56.928097
# min         1.000000       2015.0      1.000000             1.000000
# 25%       198.000000       2015.0     46.000000            23.000000
# 50%       394.000000       2015.0    111.000000            66.000000
# 75%       536.000000       2015.0    131.000000           116.000000
# max       820.000000       2015.0    201.000000           189.000000

# %%
# Histogram: Programme ID
plt.figure(figsize=(8, 5))
sns.histplot(df['programme_id'], bins=30, kde=True)
plt.title("Distribution of Programme ID")
plt.xlabel("Programme ID")
plt.ylabel("Frequency")
plt.show()

# %%
# Boxplot: Programme ID
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['programme_id'])
plt.title("Boxplot of Programme ID")
plt.show()

# %%
# Countplot: Level
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='levell')
plt.title("Count of Students by Level")
plt.xlabel("Level")
plt.ylabel("Count")
plt.show()

# %%
# Bar Plot – Distribution of Program Types
plt.figure(figsize=(6,4))
sns.countplot(x='type', data=df, palette='Set2')
plt.title('Distribution of Program Types')
plt.xlabel('Program Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_16096\2481287446.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='type', data=df, palette='Set2')

# %%
# Bar Plot – Levels of Study
plt.figure(figsize=(6,4))
sns.countplot(x='levell', data=df, palette='Set3')
plt.title('Distribution of Levels of Study')
plt.xlabel('Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_16096\679262500.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='levell', data=df, palette='Set3')

# %%
# Top 10 Discipline Groups
plt.figure(figsize=(10,5))
top_disciplines = df['discipline_group'].value_counts().nlargest(10)
sns.barplot(x=top_disciplines.values, y=top_disciplines.index, palette='coolwarm')
plt.title('Top 10 Discipline Groups')
plt.xlabel('Count')
plt.ylabel('Discipline Group')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_16096\3256731609.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_disciplines.values, y=top_disciplines.index, palette='coolwarm')

# %%
# ========== BIVARIATE ANALYSIS ==========

# %%
# Scatterplot: Programme ID vs Discipline Group ID
plt.figure(figsize=(7, 5))
sns.scatterplot(data=df, x='programme_id', y='discipline_group_id', hue='type')
plt.title("Programme vs Discipline Group")
plt.show()

# %%
# Correlation Matrix
num_df = df.select_dtypes(include=['int64', 'float64'])
corr = num_df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()

# Cross-tab: Level vs Type
ct = pd.crosstab(df['levell'], df['type'])
print("\nCross-tabulation: Level vs Type")
print(ct)
# Out:
# Cross-tabulation: Level vs Type
# type            Both  General  Self Financing
# levell
# Certificate        0      470             115
# Diploma           12     1200            1000
# Integrated        66     2575            1635
# M.Phil.           70     2391             577
# PG Diploma        14      651             565
# Ph.D.            378     5185            1851
# Post Graduate   1970    16800            9501
# Under Graduate   684     9307           11000

# %%
# Count Plot – Level vs Program Type
plt.figure(figsize=(6,4))
sns.countplot(x='levell', hue='type', data=df, palette='Set1')
plt.title('Level of Study by Program Type')
plt.xlabel('Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Discipline Group vs Level (Top 10 Only)
plt.figure(figsize=(10,5))
top_disc = df['discipline_group'].value_counts().nlargest(10).index
sns.countplot(y='discipline_group', hue='levell', data=df[df['discipline_group'].isin(top_disc)], palette='Set2')
plt.title('Top Discipline Groups by Level')
plt.xlabel('Count')
plt.ylabel('Discipline Group')
plt.tight_layout()
plt.show()

# %%
# Box Plot – Programme ID by Level
plt.figure(figsize=(8,4))
sns.boxplot(x='levell', y='programme_id', data=df, palette='coolwarm')
plt.title('Programme ID Distribution by Level')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Cross Tab – Level and Type
cross_tab = pd.crosstab(df['levell'], df['type'])
print("Cross Tabulation of Level and Program Type:\n")
print(cross_tab)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_16096\2483638097.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='levell', y='programme_id', data=df, palette='coolwarm')
# Cross Tabulation of Level and Program Type:
#
# type            Both  General  Self Financing
# levell
# Certificate        0      470             115
# Diploma           12     1200            1000
# Integrated        66     2575            1635
# M.Phil.           70     2391             577
# PG Diploma        14      651             565
# Ph.D.            378     5185            1851
# Post Graduate   1970    16800            9501
# Under Graduate   684     9307           11000

# %%
# ========== MULTIVARIATE ANALYSIS ==========

# %%
# Pairplot of numeric columns
sns.pairplot(num_df.sample(500), diag_kind='kde')  # Sample for performance
plt.suptitle("Pairplot of Numerical Features", y=1.02)
plt.show()

# %%
# Grouped Mean Analysis: Mean Programme ID by Level and Type
grouped = df.groupby(['levell', 'type'])['programme_id'].mean().unstack()
grouped.plot(kind='bar', figsize=(8, 5))
plt.title("Mean Programme ID by Level and Type")
plt.ylabel("Mean Programme ID")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Heatmap of Grouped Data
plt.figure(figsize=(6, 4))
sns.heatmap(grouped, annot=True, fmt=".1f", cmap="coolwarm")
plt.title("Heatmap: Programme ID by Level and Type")
plt.show()

# %%
# Heatmap – Correlation Matrix
plt.figure(figsize=(8,6))
numeric_cols = ['University_id', 'programme_id', 'discipline_group_id']
corr = df[numeric_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %%
# Pair Plot – Numeric Columns
sns.pairplot(df[numeric_cols], diag_kind='kde', plot_kws={'alpha': 0.5})
plt.suptitle("Pair Plot of Numeric Variables", y=1.02)
plt.show()

# %%
# Grouped Bar Plot – Level + Type + Discipline
grouped = df.groupby(['levell', 'type'])['discipline_group'].count().reset_index()
plt.figure(figsize=(10,6))
sns.barplot(data=grouped, x='levell', y='discipline_group', hue='type', palette='magma')
plt.title('Discipline Group Count by Level and Type')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Stacked Bar – University vs Level and Type (Top 5 Universities)
top_universities = df['University_name'].value_counts().nlargest(5).index
filtered_df = df[df['University_name'].isin(top_universities)]

pivot_table = pd.crosstab(index=filtered_df['University_name'], 
                          columns=[filtered_df['levell'], filtered_df['type']])

pivot_table.plot(kind='bar', stacked=True, figsize=(12,6), colormap='viridis')
plt.title('Enrollment by Level and Type – Top 5 Universities')
plt.ylabel('Count')
plt.xlabel('University')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# ========== CONCLUSION ==========

print("""
Conclusion:
- The dataset contains over 68,000 rows with detailed enrollment information.
- Most students are in undergraduate and postgraduate levels.
- There’s clear variation in programme types across disciplines.
- Some numeric features are weakly correlated, suggesting independent dimensions.
- Visualizations like heatmaps and scatter plots reveal patterns by discipline group and level.
""")
# Out:
# Conclusion:
# - The dataset contains over 68,000 rows with detailed enrollment information.
# - Most students are in undergraduate and postgraduate levels.
# - There’s clear variation in programme types across disciplines.
# - Some numeric features are weakly correlated, suggesting independent dimensions.
# - Visualizations like heatmaps and scatter plots reveal patterns by discipline group and level.
